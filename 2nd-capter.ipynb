# %%
import numpy as np
import pandas as pd
from sklearn  import linear_model
import matplotlib.pyplot as plt

# %%
data =pd.read_csv('/kaggle/input/machine-2nd/2nd_capter.csv')
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
data.head(2)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000

# %%
data.tail(1)
# Out:
#    area   price
# 4  4000  725000

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(data.area,data.price,color='red',marker='*')

# %%
new_data = data.drop('price',axis='columns')
new_data
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price =data.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
reg = linear_model.LinearRegression()
reg.fit(new_data,price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg. coef_
# Out:
# array([135.78767123])

# %%
reg. intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# 3300 *135.78767123 +180616.43835616432

# %%
 plt.xlabel('area')
 plt.ylabel('price')
 plt.scatter(data.area,data.price,color='red',marker='+')
 plt.plot(new_data,reg.predict(new_data))
