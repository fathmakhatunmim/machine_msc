# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv('/kaggle/input/insurance/insurance_data.csv')
data
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
data.describe()
# Out:
#              age  bought_insurance
# count  27.000000         27.000000
# mean   39.666667          0.518519
# std    15.745573          0.509175
# min    18.000000          0.000000
# 25%    25.000000          0.000000
# 50%    45.000000          1.000000
# 75%    54.500000          1.000000
# max    62.000000          1.000000

# %%
plt.scatter(data.age,data.bought_insurance,marker='*',color='red')

# %%
data.shape
# Out:
# (27, 2)

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['age']],data.bought_insurance,test_size=0.1)

# %%
x_train
# Out:
#     age
# 22   40
# 6    55
# 1    25
# 8    62
# 20   21
# 3    52
# 24   50
# 12   27
# 10   18
# 0    22
# 19   18
# 21   26
# 9    61
# 15   55
# 26   23
# 25   54
# 11   28
# 23   45
# 2    47
# 14   49
# 17   58
# 18   19
# 16   25
# 5    56

# %%
y_train
# Out:
# 22    1
# 6     0
# 1     0
# 8     1
# 20    0
# 3     0
# 24    1
# 12    0
# 10    0
# 0     0
# 19    0
# 21    0
# 9     1
# 15    1
# 26    0
# 25    1
# 11    0
# 23    1
# 2     1
# 14    1
# 17    1
# 18    0
# 16    1
# 5     1
# Name: bought_insurance, dtype: int64

# %%
x_test
# Out:
#     age
# 4    46
# 13   29
# 7    60

# %%
y_test
# Out:
# 4     1
# 13    0
# 7     1
# Name: bought_insurance, dtype: int64

# %%
model =linear_model.LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 1])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)
# Out:
# array([[0.29722836, 0.70277164],
#        [0.78142492, 0.21857508],
#        [0.06796536, 0.93203464]])
